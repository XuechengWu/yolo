# %% [markdown]
# <a href="https://colab.research.google.com/github/XuechengWu/yolo/blob/main/YOLOv5_detecte_online_V02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Allgemein Setup

# %%
# !wget https://dl-web.dropbox.com/s/fhg7l06klfu2qu0/yolov5-master.zip  # clone
# !unzip yolov5-master.zip
# %cd yolov5-master
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 2022-5-31 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
# !nvidia-smi
# Out:
# Wed Jun  1 22:37:16 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# srcfile 需要复制、移动的文件   
# dstpath 目的地址
 
def mycopyfile(srcfile,dstpath):                       # 复制函数
    if not os.path.isfile(srcfile):
        print ("%s not exist!"%(srcfile))
    else:
        fpath,fname=os.path.split(srcfile)             # 分离文件名和路径
        if not os.path.exists(dstpath):
            os.makedirs(dstpath)                       # 创建路径
        shutil.copy(srcfile, dstpath + fname)          # 复制文件
        print ("copy %s -> %s"%(srcfile, dstpath + fname))
 
 
# src_dir = './'

# %%
import os

def delete_space(buff_dir):
    for files_name in os.listdir(buff_dir):
        if len(files_name.split(" ")) >1:
            os.rename(os.path.join(buff_dir,files_name),
                      os.path.join(buff_dir,files_name.replace(" ","_")))
            print(os.path.join(buff_dir,files_name.replace(" ","_")))

# %% [markdown]
# # Bearbeiten mit .pt Weight
# saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# download weight.pt
# !wget https://dl-web.dropbox.com/s/f5psunxkn1ic2yj/best.pt
mycopyfile('/content/best.pt', '/content/yolov5-master/')
# Out:
# --2022-06-01 22:37:54--  https://dl-web.dropbox.com/s/f5psunxkn1ic2yj/best.pt
# Resolving dl-web.dropbox.com (dl-web.dropbox.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to dl-web.dropbox.com (dl-web.dropbox.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/s/f5psunxkn1ic2yj/best.pt [following]
# --2022-06-01 22:37:54--  https://dl.dropboxusercontent.com/s/f5psunxkn1ic2yj/best.pt
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14359413 (14M) [application/octet-stream]
# Saving to: ‘best.pt’
#
# best.pt             100%[===================>]  13.69M  83.6MB/s    in 0.2s
#
# 2022-06-01 22:37:55 (83.6 MB/s) - ‘best.pt’ saved [14359413/14359413]
#
# ...

# %%
# download oringinal Video

mycopyfile('/content/drive/MyDrive/Abschlussarbeit/videoMaterial/63x_Oilimmersion_5%_OrmoComp/2.5%SCA Professor v2.9.4 [fabrication1] 2022-04-04 16-16-53.mp4', '/content/')
# Out:
# copy /content/drive/MyDrive/Abschlussarbeit/videoMaterial/63x_Oilimmersion_5%_OrmoComp/2.5%SCA Professor v2.9.4 [fabrication1] 2022-04-04 16-16-53.mp4 -> /content/2.5%SCA Professor v2.9.4 [fabrication1] 2022-04-04 16-16-53.mp4

# %%
delete_space("/content")
# Out:
# /content/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4

# %%
# Video bearbeiten
# weight.pt nutzen
# !python detect.py --weights best.pt --img 640 --conf 0.25 --source /content/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4
# Out:
# detect: weights=['best.pt'], source=/content/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-5-31 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1296) /content/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4: 352x640 1 Laser, Done. (0.021s)
# video 1/1 (2/1296) /content/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4: 352x640 1 Laser, Done. (0.011s)
# ...

# %%
# download Bearbeitet_Video

mycopyfile( '/content/yolov5-master/runs/detect/exp4/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4', '/content/drive/MyDrive/Abschlussarbeit/videoErgebnis/')
# Out:
# copy /content/yolov5-master/runs/detect/exp4/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4 -> /content/drive/MyDrive/Abschlussarbeit/videoErgebnis/2.5%SCA_Professor_v2.9.4_[fabrication1]_2022-04-04_16-16-53.mp4
